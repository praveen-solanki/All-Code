# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "train", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 350 images belonging to 7 classes.
# {'Angry': 0,
#  'Disguist': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "train", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 350 images belonging to 7 classes.

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 6:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="models/emotion/best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[es,mc])
# Out:
# C:\Users\praveen solanki\AppData\Local\Temp\ipykernel_10232\564963302.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_data,
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 8.6517 - accuracy: 0.2358
# Epoch 00001: val_accuracy improved from -inf to 0.53516, saving model to best_model.h5
# 10/10 [==============================] - 50s 5s/step - loss: 8.6517 - accuracy: 0.2358 - val_loss: 3.8143 - val_accuracy: 0.5352
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 3.2727 - accuracy: 0.5881
# Epoch 00002: val_accuracy improved from 0.53516 to 0.81641, saving model to best_model.h5
# 10/10 [==============================] - 41s 4s/step - loss: 3.2727 - accuracy: 0.5881 - val_loss: 1.1031 - val_accuracy: 0.8164
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 1.8306 - accuracy: 0.7344
# Epoch 00003: val_accuracy improved from 0.81641 to 0.82031, saving model to best_model.h5
# 10/10 [==============================] - 42s 4s/step - loss: 1.8306 - accuracy: 0.7344 - val_loss: 0.7578 - val_accuracy: 0.8203
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 0.7457 - accuracy: 0.8428
# Epoch 00004: val_accuracy improved from 0.82031 to 0.91797, saving model to best_model.h5
# 10/10 [==============================] - 42s 4s/step - loss: 0.7457 - accuracy: 0.8428 - val_loss: 0.3149 - val_accuracy: 0.9180
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 0.3940 - accuracy: 0.8962
# Epoch 00005: val_accuracy improved from 0.91797 to 0.92969, saving model to best_model.h5
# 10/10 [==============================] - 44s 4s/step - loss: 0.3940 - accuracy: 0.8962 - val_loss: 0.2235 - val_accuracy: 0.9297
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 0.3279 - accuracy: 0.9182
# Epoch 00006: val_accuracy improved from 0.92969 to 0.95312, saving model to best_model.h5
# 10/10 [==============================] - 27s 3s/step - loss: 0.3279 - accuracy: 0.9182 - val_loss: 0.1524 - val_accuracy: 0.9531
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 0.4041 - accuracy: 0.9245
# Epoch 00007: val_accuracy improved from 0.95312 to 0.97656, saving model to best_model.h5
# 10/10 [==============================] - 26s 3s/step - loss: 0.4041 - accuracy: 0.9245 - val_loss: 0.0991 - val_accuracy: 0.9766
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 0.3019 - accuracy: 0.9371
# Epoch 00008: val_accuracy improved from 0.97656 to 0.98438, saving model to best_model.h5
# 10/10 [==============================] - 28s 3s/step - loss: 0.3019 - accuracy: 0.9371 - val_loss: 0.0376 - val_accuracy: 0.9844
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 0.2071 - accuracy: 0.9403
# Epoch 00009: val_accuracy did not improve from 0.98438
# 10/10 [==============================] - 30s 3s/step - loss: 0.2071 - accuracy: 0.9403 - val_loss: 0.1269 - val_accuracy: 0.9609
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 0.2648 - accuracy: 0.9465
# Epoch 00010: val_accuracy improved from 0.98438 to 0.99219, saving model to best_model.h5
# 10/10 [==============================] - 27s 3s/step - loss: 0.2648 - accuracy: 0.9465 - val_loss: 0.0209 - val_accuracy: 0.9922
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1160 - accuracy: 0.9686
# Epoch 00011: val_accuracy did not improve from 0.99219
# 10/10 [==============================] - 25s 3s/step - loss: 0.1160 - accuracy: 0.9686 - val_loss: 0.0598 - val_accuracy: 0.9805
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0730 - accuracy: 0.9780
# Epoch 00012: val_accuracy improved from 0.99219 to 0.99609, saving model to best_model.h5
# 10/10 [==============================] - 26s 3s/step - loss: 0.0730 - accuracy: 0.9780 - val_loss: 0.0091 - val_accuracy: 0.9961
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9843
# Epoch 00013: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 27s 3s/step - loss: 0.0380 - accuracy: 0.9843 - val_loss: 0.0336 - val_accuracy: 0.9844
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9843
# Epoch 00014: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 27s 3s/step - loss: 0.0404 - accuracy: 0.9843 - val_loss: 0.0138 - val_accuracy: 0.9922
# Epoch 15/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9843
# Epoch 00015: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 27s 3s/step - loss: 0.0371 - accuracy: 0.9843 - val_loss: 0.0169 - val_accuracy: 0.9961
# Epoch 00015: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "train/angry/download (1).jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
#  the image is of Angry
